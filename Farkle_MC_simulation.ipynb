# %%
from collections import Counter
import random
from functools import reduce
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## calculate score each roll

# %%
def getScore(dice):
    ''' takes in a list of dice number and sum up all the possible scores(include single ones and fives)
    Returns the scores, the number of dice left unscored, and the dictionary stores the dice number and the count'''
    dice.sort()
    counter = Counter(dice) # gives a dictionary stores the dice number and the count
    if len(dice)==6:   # cases score all six dice
        if dice == [1,2,3,4,5,6]: # a 1-6 straight 
            return 1500, 0, counter
        elif any(counter[i]==6 for i in counter): # 6 of a kind
            return 3000, 0, counter
        elif any(dice.count(i)==4 and dice.count(j)==2 for i in range(1,7) for j in range(1,7)): # 4 of a kind and a pair
            return 1500, 0, counter
        elif dice[0]==dice[1]==dice[2] and dice[3]==dice[4]==dice[5]: # two triplets
            return 2500, 0, counter
        elif dice[0]==dice[1] and dice[2]==dice[3] and dice[4]==dice[5]: # three pairs
            return 1500, 0, counter

    # cases score some dice in combanition plus individual ones and fives
    sum = 0
    for i in counter:
        if counter[i]==5: # 5 of a kind plus some single ones and fives
            sum += 2000
            oneFiveSum, count = oneFiveScoreCount(i, counter, dice)
            sum += oneFiveSum
            count += 5
            return sum, len(dice)-count, counter
        elif counter[i]==4: # 4 of a kind plus some single ones and fives
            sum += 1000
            oneFiveSum, count = oneFiveScoreCount(i, counter, dice)
            sum += oneFiveSum
            count += 4
            return sum, len(dice)-count, counter
        elif counter[i]==3: # 3 of a kind plus some single ones and fives
            if i==1:
                sum += 1000
            else:
                sum += i*100
            oneFiveSum, count = oneFiveScoreCount(i, counter, dice)
            sum += oneFiveSum
            count += 3
            return sum, len(dice)-count, counter
        
    # no combinations, only sum up socres of ones and fives
    oneFiveSum, count = oneFiveScoreCount(-1, counter, dice)
    return oneFiveSum, len(dice)-count, counter

def oneFiveScoreCount(curr_num, counter, dice):
    '''takes in current number, counter, and dice list.
    Returns the sum score of single ones and fives and their total count'''
    score = 0
    count = 0
    if curr_num!=1:
        score += counter[1]*100
        count += counter[1]
    if curr_num!=5:
        score += counter[5]*50
        count += counter[5]
    return score, count

# %% [markdown]
# ## Strategies

# %%
def hotDice(score, numDice):
    '''check if the roll is in the hotDice situation that get score with all six dice'''
    if score!=0 and numDice==0:
        return True
    else:
        return False

# %%
def rollDice(numDice):
    '''roll dice'''
    return [random.randint(1, 6) for x in range(numDice)]

# %%
def strategy1(minScore, numDiceThresh):
    '''strategy 1:
    takes in a minimum score requirement, and a number of dice threshold.
    Keep rolling dices if you haven't meet the minimum score requirement,
    or the number of dice is higher than the threshold.
    Return the total score get in this turn.'''
    score, numDice = 0, 6
    while score < minScore or numDice > numDiceThresh:
        dice = rollDice(numDice)
        rollScore, numDice, counter = getScore(dice)
        # farkle situation, get 0 score
        if rollScore==0:
            return 0
        score += rollScore
        # hotDice situation, roll again
        if hotDice(rollScore, numDice):
            HDRollScore = strategy1(minScore-score, numDiceThresh)
            # if farkle in HotDice turn, lose all the points as well
            if HDRollScore == 0:
                return 0
            else:
                score += HDRollScore
    # minimum score requirement
    if score < minScore:
        return 0
    else:
        return score

# %%
def strategy2(minScore, scoreThresh):
    '''strategy 2:
    takes in a minimum score requirement, a score threshold.
    Keep rolling dices if you haven't meet the minimum score requirement,
    or score is lower than the threshold.
    Return the total score get in this turn.'''
    score, numDice = 0, 6
    while score < minScore or score < scoreThresh:
        dice = rollDice(numDice)
        rollScore, numDice, counter = getScore(dice)
        # farkle situation, get 0 score
        if rollScore==0:
            return 0
        score += rollScore
        # hotDice situation, roll again
        if hotDice(rollScore, numDice):
            HDRollScore = strategy2(minScore-score, scoreThresh-score)
            # if farkle in HotDice turn, lose all the points as well
            if HDRollScore == 0:
                return 0
            else:
                score += HDRollScore
    # minimum score requirement
    if score < minScore:
        return 0
    else:
        return score

# %%
def strategy3(minScore, scoreThresh, numDiceThresh):
    '''strategy 3:
    takes in a minimum score requirement, a score threshold, and a number of dice threshold.
    Keep rolling dices if you haven't meet the minimum score requirement,
    or score is lower than the threshold and the number of dice is higher than the threshold.
    Return the total score get in this turn.'''
    score, numDice = 0, 6
    while score < minScore or (numDice > numDiceThresh and score < scoreThresh):
        dice = rollDice(numDice)
        rollScore, numDice, counter = getScore(dice)
        # farkle situation, get 0 score
        if rollScore==0:
            return 0
        score += rollScore
        # hotDice situation, roll again
        if hotDice(rollScore, numDice):
            HDRollScore = strategy3(minScore-score, scoreThresh-score, numDiceThresh)
            # if farkle in HotDice turn, lose all the points as well
            if HDRollScore == 0:
                return 0
            else:
                score += HDRollScore
    # minimum score requirement
    if score < minScore:
        return 0
    else:
        return score

# %%
def strategy4(minScore, numDiceThresh):
    '''strategy 4:
    takes in a minimum score requirement and number of dice threshold.
    Keep rolling dices if you haven't meet the minimum score requirement,
    or the number of dice is higher than the threshold.
    If you have more than four dice and have some 1s or 5s, do not take triplet 2s or 3s.
    If you have more than three dice and no combination appear, only take one 1 if you have 1
    or take one 5 if you don't have 1.
    Return the total score get in this turn.'''
    score, numDice = 0, 6
    while score < minScore or numDice > numDiceThresh:
        oriNumDice = numDice
        dice = rollDice(numDice)
        rollScore, numDice, counter = getScore(dice)
        # farkle situation, get 0 score
        if rollScore==0:
            return 0

        # hotDice situation, roll again
        if hotDice(rollScore, numDice):
            HDRollScore = strategy4(minScore-score, numDiceThresh)
            # if farkle in HotDice turn, lose all the points as well
            if HDRollScore == 0:
                return 0
            else:
                score += HDRollScore
        else:
            # do not take triplet 2 or 3 in specific situation
            if oriNumDice>4:
                if counter[2]==3 and len(counter)>2 and (counter[1]!=0 or counter[5]!=0):
                    rollScore -= 200
                    numDice += 3
                if counter[3]==3 and len(counter)>2 and (counter[1]!=0 or counter[5]!=0):
                    rollScore -= 300
                    numDice += 3
            # take only one 1 or 5 in some situation
            if oriNumDice>3 and all(counter[i]<3 for i in counter):
                if counter[1]>0:
                    rollScore -= 100*(counter[1]-1) + 50*counter[5]
                    numDice += counter[1] + counter[5] - 1
                elif counter[5]>0:
                    rollScore -= 50*(counter[5]-1)
                    numDice += counter[5]-1
        score += rollScore
    # minimum score requirement
    if score < minScore:
        return 0
    else:
        return score

# %%
def strategy5(minScore, scoreThresh):
    '''strategy 5:
    takes in a minimum score requirement, a score threshold.
    Keep rolling dices if you haven't meet the minimum score requirement,
    or score is lower than the threshold.
    If you have more than four dice and have some 1s or 5s, do not take triplet 2s or 3s.
    If you have more than three dice and no combination appear, only take one 1 if you have 1
    or take one 5 if you don't have 1.
    Return the total score get in this turn.'''
    score, numDice = 0, 6
    while score < minScore or score < scoreThresh:
        oriNumDice = numDice
        dice = rollDice(numDice)
        # print("dice: ", dice)
        rollScore, numDice, counter = getScore(dice)
        # farkle situation, get 0 score
        if rollScore==0:
            return 0

        # hotDice situation, roll again
        if hotDice(rollScore, numDice):
            HDRollScore = strategy5(minScore-score, scoreThresh)
            # if farkle in HotDice turn, lose all the points as well
            if HDRollScore == 0:
                return 0
            else:
                score += HDRollScore
        else:
            # do not take triplet 2 or 3 in specific situation
            if oriNumDice>4:
                if counter[2]==3 and len(counter)>2 and (counter[1]!=0 or counter[5]!=0):
                    rollScore -= 200
                    numDice += 3
                if counter[3]==3 and len(counter)>2 and (counter[1]!=0 or counter[5]!=0):
                    rollScore -= 300
                    numDice += 3
            # take only one 1 or 5 in some situation
            if oriNumDice>3 and all(counter[i]<3 for i in counter):
                if counter[1]>0:
                    rollScore -= 100*(counter[1]-1) + 50*counter[5]
                    numDice += counter[1] + counter[5] - 1
                elif counter[5]>0:
                    rollScore -= 50*(counter[5]-1)
                    numDice += counter[5]-1
        score += rollScore
    # minimum score requirement
    if score < minScore:
        return 0
    else:
        return score

# %%
def strategy6(minScore, scoreThresh, numDiceThresh):
    '''strategy 6:
    takes in a minimum score requirement, a score threshold, and a number of dice threshold.
    Keep rolling dices if you haven't meet the minimum score requirement,
    or score is lower than the threshold and the number of dice is higher than the threshold.
    If you have more than four dice and have some 1s or 5s, do not take triplet 2s or 3s.
    If you have more than three dice and no combination appear, only take one 1 if you have 1
    or take one 5 if you don't have 1.
    Return the total score get in this turn.'''
    score, numDice = 0, 6
    while score < minScore or (numDice > numDiceThresh and score < scoreThresh):
        oriNumDice = numDice
        dice = rollDice(numDice)
        rollScore, numDice, counter = getScore(dice)
        # farkle situation, get 0 score
        if rollScore==0:
            return 0

        # hotDice situation, roll again
        if hotDice(rollScore, numDice):
            HDRollScore = strategy6(minScore-score, scoreThresh-score, numDiceThresh)
            # if farkle in HotDice turn, lose all the points as well
            if HDRollScore == 0:
                return 0
            else:
                score += HDRollScore
        else:
            # do not take triplet 2 or 3 in specific situation
            if oriNumDice>4:
                if counter[2]==3 and len(counter)>2 and (counter[1]!=0 or counter[5]!=0):
                    rollScore -= 200
                    numDice += 3
                if counter[3]==3 and len(counter)>2 and (counter[1]!=0 or counter[5]!=0):
                    rollScore -= 300
                    numDice += 3
            # take only one 1 or 5 in some situation
            if oriNumDice>3 and all(counter[i]<3 for i in counter):
                if counter[1]>0:
                    rollScore -= 100*(counter[1]-1) + 50*counter[5]
                    numDice += counter[1] + counter[5] - 1
                elif counter[5]>0:
                    rollScore -= 50*(counter[5]-1)
                    numDice += counter[5]-1
        score += rollScore
    # minimum score requirement
    if score < minScore:
        return 0
    else:
        return score

# %% [markdown]
# ## Strategy Comparison

# %% [markdown]
# ### Strategy 1 comparison

# %%
class Player:

    def __init__(self, total_score, wins, win_prob):
        self.total_score = total_score
        self.wins = wins
        self.win_prob = win_prob

    def CI(self):
        return min(self.win_prob), max(self.win_prob)

    def reset_score(self):
        self.total_score = 0

    def reset_wins(self):
        self.wins = 0

# %%
numRun = 1000
minScore = 0
numPlayers = 4
players = [None] * numPlayers
for numP in range(numPlayers): players[numP] = Player(0, 0, [])
for k in range(1000):
    for player in players: player.reset_wins()
    for l in range(numRun):
        for player in players: player.reset_score()
        winner = False
        for m in range(100):
            players[0].total_score += strategy1(minScore, 3)
            players[1].total_score += strategy1(minScore, 2)
            players[2].total_score += strategy1(minScore, 2)
            players[3].total_score += strategy1(minScore, 2)
            for player in players:
                if player.total_score >= 10000:
                    player.wins += 1
                    winner = True
            if winner: break
    players[0].win_prob.append(player.wins / numRun)

plt.hist(players[0].win_prob())
# Out:
# 4800

# %%
prob = np.zeros((6,6))

wins = [0,0,0,0,0,0]
numRun = 10000
minScore = 0
for k in range(10):
    for i in range(numRun):
        score = [0,0,0,0,0,0]
        for j in range(100):
            score[0] += strategy1(minScore, 1)
            score[1] += strategy1(minScore, 2)
            score[2] += strategy1(minScore, 3)
            score[3] += strategy1(minScore, 4)
            score[4] += strategy1(minScore, 5)
            score[5] += strategy1(minScore, 6)
            if any(score[i]>=10000 for i in range(len(score))):
                score[0] += strategy1(minScore, 1)
                score[1] += strategy1(minScore, 2)
                score[2] += strategy1(minScore, 3)
                score[3] += strategy1(minScore, 4)
                score[4] += strategy1(minScore, 5)
                score[5] += strategy1(minScore, 6)
                wins[score.index(max(score))] += 1
                break
        # print("score1: ", score[0], "score2: ", score[1], "score3: ", score[2],
        #     "score4: ", score[3], "score5: ", score[4], "score6: ", score[5])
    print(wins[0]/numRun, wins[1]/numRun, wins[2]/numRun, wins[3]/numRun, wins[4]/numRun, wins[5]/numRun)
# Out:
# 0.0917 0.2733 0.2797 0.2093 0.146 0.0
# 0.1923 0.5411 0.5658 0.415 0.2858 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb Cell 15 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> score = [0,0,0,0,0,0]
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> for j in range(100):
# ---> <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a>     score[0] += strategy1(minScore, 1)
#      <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a>     score[1] += strategy1(minScore, 2)
#      <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a>     score[2] += strategy1(minScore, 3)
#
# /Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb Cell 15 in strategy1(minScore, numDiceThresh)
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a> score, numDice = 0, 6
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> while score < minScore or numDice > numDiceThresh:
# ----> <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a>     dice = rollDice(numDice)
#      <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a>     rollScore, numDice, counter = getScore(dice)
#      <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a>     # farkle situation, get 0 score
#
# /Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb Cell 15 in rollDice(numDice)
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> def rollDice(numDice):
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a>     '''roll dice'''
# ----> <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     return [random.randint(1, 6) for x in range(numDice)]
#
# /Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb Cell 15 in <listcomp>(.0)
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> def rollDice(numDice):
#       <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a>     '''roll dice'''
# ----> <a href='vscode-notebook-cell:/Users/apple/Desktop/math381/hw6/Farkle_MC_simulation.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     return [random.randint(1, 6) for x in range(numDice)]
#
# File ~/opt/anaconda3/envs/cse163/lib/python3.9/random.py:338, in Random.randint(self, a, b)
#     334 def randint(self, a, b):
#     335     """Return random integer in range [a, b], including both end points.
#     336     """
# --> 338     return self.randrange(a, b+1)
#
# File ~/opt/anaconda3/envs/cse163/lib/python3.9/random.py:314, in Random.randrange(self, start, stop, step)
#     312 width = istop - istart
#     313 if step == 1 and width > 0:
# --> 314     return istart + self._randbelow(width)
#     315 if step == 1:
#     316     raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#
# KeyboardInterrupt:

# %%
prob = np.array([[], [], [], [], [], []])
numRun = 1000
minScore = 0
numPlayers = 6
for i in range(6):
    for j in range(6):
        players=[None]*numPlayers
        for numP in range(numPlayers): players[numP] = Player(0,[])
        for k in range(10):
            for l in range(numRun):
                for m in range(100):
                    players[0].score += strategy1(minScore, i)
                    players[1].score += strategy1(minScore, j)
                    players[2].score += strategy1(minScore, j)
                    players[3].score += strategy1(minScore, j)
                    players[4].score += strategy1(minScore, j)
                    players[5].score += strategy1(minScore, j)
                    if any(ply.score>=10000 for ply in players):
                        for m in range(6):
                            if score[m] != score.index(max(score)):
                                if m == i:
                                    score[m] += strategy1(minScore, i)
                                else:
                                    score[m] += strategy1(minScore, j)
                        wins[score.index(max(score))] += 1
                        break
# Out:
#   Input In [51]
#
#     ^
# IndentationError: expected an indented block

# %%
# def compare_stategies():
aa = [1,3,2,6,3,5,8,9]
min(aa)
# Out:
# 1

# %%
wins = [0,0,0,0,0,0]
numRun = 10000
minScore = 0
for k in range(10):
    for i in range(numRun):
        score = [0,0,0,0,0,0]
        for j in range(100):
            score[0] += strategy1(minScore, 2)
            score[1] += strategy2(minScore, 500)
            score[2] += strategy3(minScore, 500, 2)
            score[3] += strategy4(minScore, 2)
            score[4] += strategy5(minScore, 500)
            score[5] += strategy6(minScore, 500, 2)
            if any(score[i]>=10000 for i in range(len(score))):
                score[0] += strategy1(minScore, 2)
                score[1] += strategy2(minScore, 500)
                score[2] += strategy3(minScore, 500, 2)
                score[3] += strategy4(minScore, 2)
                score[4] += strategy5(minScore, 500)
                score[5] += strategy6(minScore, 500, 2)
                wins[score.index(max(score))] += 1
                break
        # print("score1: ", score[0], "score2: ", score[1], "score3: ", score[2],
        #     "score4: ", score[3], "score5: ", score[4], "score6: ", score[5])
    print(wins[0]/numRun, wins[1]/numRun, wins[2]/numRun, wins[3]/numRun, wins[4]/numRun, wins[5]/numRun)
# Out:
# score1:  8900 score2:  7650 score3:  6350 score4:  10400 score5:  6700 score6:  9850
# score1:  1900 score2:  4700 score3:  5650 score4:  6950 score5:  10450 score6:  8700
# score1:  11100 score2:  6150 score3:  7150 score4:  5900 score5:  5500 score6:  8750
# score1:  7050 score2:  8900 score3:  6000 score4:  9100 score5:  6050 score6:  10250
# score1:  10450 score2:  5400 score3:  3300 score4:  3250 score5:  4300 score6:  10900
# score1:  13550 score2:  1850 score3:  4000 score4:  5700 score5:  6600 score6:  6900
# score1:  10100 score2:  5100 score3:  6800 score4:  11750 score5:  4150 score6:  10400
# score1:  11950 score2:  5850 score3:  3300 score4:  3850 score5:  5500 score6:  4900
# score1:  4700 score2:  5500 score3:  2350 score4:  8900 score5:  4700 score6:  12400
# score1:  3100 score2:  1100 score3:  3900 score4:  10750 score5:  3500 score6:  2150
# score1:  10150 score2:  4500 score3:  3350 score4:  4450 score5:  2950 score6:  9750
# score1:  10300 score2:  3000 score3:  5500 score4:  4250 score5:  5950 score6:  6700
# score1:  11900 score2:  3200 score3:  1700 score4:  9900 score5:  8550 score6:  6950
# score1:  12250 score2:  7500 score3:  7550 score4:  8650 score5:  9650 score6:  5000
# score1:  6350 score2:  2700 score3:  2500 score4:  11200 score5:  6050 score6:  7950
# score1:  10750 score2:  5000 score3:  2650 score4:  6950 score5:  6950 score6:  6000
# score1:  12250 score2:  5500 score3:  5450 score4:  7850 score5:  5700 score6:  5350
# score1:  6850 score2:  8000 score3:  5550 score4:  7050 score5:  10500 score6:  9450
# score1:  10250 score2:  4950 score3:  4650 score4:  6900 score5:  3850 score6:  6300
# score1:  8700 score2:  8400 score3:  2050 score4:  4300 score5:  10250 score6:  12450
# score1:  5200 score2:  3350 score3:  2850 score4:  7300 score5:  12450 score6:  7200
# score1:  6650 score2:  2900 score3:  3250 score4:  1850 score5:  11100 score6:  8750
# score1:  11000 score2:  5150 score3:  4650 score4:  5600 score5:  6550 score6:  7200
# score1:  10450 score2:  3900 score3:  3950 score4:  6750 score5:  5850 score6:  9200
# score1:  11900 score2:  4850 score3:  6600 score4:  4500 score5:  5850 score6:  9050
# score1:  8500 score2:  7150 score3:  5150 score4:  7600 score5:  11700 score6:  8600
# score1:  3300 score2:  2400 score3:  2150 score4:  10200 score5:  14700 score6:  7000
# score1:  6650 score2:  2700 score3:  1100 score4:  10600 score5:  3750 score6:  4200
# score1:  9900 score2:  5500 score3:  2500 score4:  10550 score5:  10950 score6:  7600
# score1:  7400 score2:  1650 score3:  3200 score4:  13350 score5:  3150 score6:  5300
# score1:  12300 score2:  2600 score3:  3650 score4:  4300 score5:  4300 score6:  6650
# score1:  7400 score2:  4500 score3:  5300 score4:  10050 score5:  10650 score6:  7750
# score1:  5750 score2:  3450 score3:  4650 score4:  10450 score5:  5600 score6:  10400
# score1:  10250 score2:  3650 score3:  5400 score4:  8050 score5:  5100 score6:  7750
# score1:  10150 score2:  4400 score3:  3250 score4:  9300 score5:  8450 score6:  10350
# score1:  10500 score2:  6100 score3:  3100 score4:  8500 score5:  13000 score6:  7900
# score1:  8350 score2:  4000 score3:  4300 score4:  9050 score5:  10800 score6:  7550
# score1:  3850 score2:  1650 score3:  700 score4:  5800 score5:  2700 score6:  12300
# score1:  11100 score2:  4250 score3:  2700 score4:  5400 score5:  2650 score6:  5300
# score1:  4900 score2:  4200 score3:  1700 score4:  6700 score5:  6100 score6:  11350
# score1:  10050 score2:  3700 score3:  9650 score4:  4750 score5:  8600 score6:  10000
# score1:  5700 score2:  3550 score3:  2500 score4:  3650 score5:  10050 score6:  6250
# score1:  7650 score2:  4500 score3:  3450 score4:  6350 score5:  10500 score6:  7250
# score1:  14700 score2:  4850 score3:  4100 score4:  12150 score5:  3350 score6:  7550
# score1:  10300 score2:  4800 score3:  2350 score4:  7100 score5:  4900 score6:  8350
# score1:  8650 score2:  4600 score3:  3150 score4:  13300 score5:  5000 score6:  5100
# score1:  4350 score2:  4250 score3:  2300 score4:  6750 score5:  5150 score6:  12100
# score1:  5900 score2:  4950 score3:  6100 score4:  9750 score5:  9500 score6:  10700
# score1:  10500 score2:  2200 score3:  3900 score4:  9400 score5:  9400 score6:  6250
# score1:  10600 score2:  3450 score3:  5450 score4:  7450 score5:  7950 score6:  9300
# score1:  10400 score2:  3250 score3:  3050 score4:  4500 score5:  6400 score6:  8100
# score1:  9500 score2:  6950 score3:  7100 score4:  10150 score5:  4950 score6:  6650
# score1:  7000 score2:  1800 score3:  3200 score4:  600 score5:  4400 score6:  10150
# score1:  6250 score2:  5300 score3:  3300 score4:  7800 score5:  9550 score6:  10600
# score1:  3800 score2:  3950 score3:  3350 score4:  11900 score5:  7800 score6:  8300
# score1:  10450 score2:  3800 score3:  4900 score4:  8700 score5:  12500 score6:  9350
# score1:  4250 score2:  2800 score3:  4350 score4:  12050 score5:  5200 score6:  6800
# score1:  10550 score2:  2050 score3:  4500 score4:  7300 score5:  5100 score6:  11650
# score1:  3150 score2:  3100 score3:  2050 score4:  3200 score5:  12150 score6:  8900
# score1:  12350 score2:  2000 score3:  2200 score4:  12250 score5:  9050 score6:  5150
# score1:  10450 score2:  6900 score3:  1700 score4:  10000 score5:  4450 score6:  10650
# score1:  6500 score2:  3450 score3:  4050 score4:  6450 score5:  10200 score6:  10100
# score1:  11850 score2:  3850 score3:  4150 score4:  7000 score5:  3650 score6:  8300
# score1:  6000 score2:  4600 score3:  9600 score4:  10800 score5:  5700 score6:  10500
# score1:  5950 score2:  2250 score3:  4400 score4:  2850 score5:  4800 score6:  10500
# score1:  9450 score2:  4400 score3:  10600 score4:  9000 score5:  8750 score6:  8100
# score1:  9250 score2:  6100 score3:  7050 score4:  10050 score5:  10050 score6:  4900
# score1:  10100 score2:  4150 score3:  4300 score4:  3350 score5:  2850 score6:  8050
# score1:  10350 score2:  3900 score3:  6550 score4:  9850 score5:  6450 score6:  10600
# score1:  12200 score2:  4950 score3:  4100 score4:  5100 score5:  7850 score6:  5750
# score1:  5050 score2:  6800 score3:  3300 score4:  12350 score5:  4900 score6:  4400
# score1:  10650 score2:  3700 score3:  3050 score4:  3700 score5:  3000 score6:  2050
# score1:  6100 score2:  4250 score3:  2050 score4:  6400 score5:  7100 score6:  11350
# score1:  8050 score2:  7150 score3:  6100 score4:  8450 score5:  8400 score6:  11000
# score1:  10350 score2:  2700 score3:  2000 score4:  6350 score5:  3500 score6:  8900
# score1:  6600 score2:  4500 score3:  7100 score4:  12250 score5:  9050 score6:  4100
# score1:  7800 score2:  4150 score3:  4400 score4:  12300 score5:  12400 score6:  11650
# score1:  10700 score2:  2050 score3:  3600 score4:  3500 score5:  3450 score6:  6150
# score1:  5050 score2:  4450 score3:  5600 score4:  10750 score5:  9400 score6:  4700
# score1:  10100 score2:  5000 score3:  1050 score4:  6800 score5:  10250 score6:  8500
# score1:  10000 score2:  3750 score3:  6350 score4:  10050 score5:  8400 score6:  9700
# score1:  6300 score2:  1200 score3:  3700 score4:  8300 score5:  7300 score6:  11600
# score1:  11450 score2:  3200 score3:  5200 score4:  11450 score5:  12650 score6:  7250
# score1:  5200 score2:  4200 score3:  2750 score4:  7350 score5:  10950 score6:  3900
# score1:  9950 score2:  2750 score3:  2050 score4:  9350 score5:  2700 score6:  10550
# score1:  8000 score2:  2250 score3:  3500 score4:  10550 score5:  3700 score6:  10300
# score1:  6500 score2:  3300 score3:  5650 score4:  6150 score5:  7950 score6:  10250
# score1:  12300 score2:  4200 score3:  3150 score4:  5000 score5:  5400 score6:  7300
# score1:  6900 score2:  1650 score3:  3150 score4:  5900 score5:  5350 score6:  10100
# score1:  12950 score2:  4050 score3:  2900 score4:  5850 score5:  6350 score6:  11000
# score1:  8500 score2:  3850 score3:  5200 score4:  10550 score5:  6550 score6:  9350
# score1:  11550 score2:  4400 score3:  5100 score4:  6450 score5:  7550 score6:  2250
# score1:  9900 score2:  7850 score3:  6450 score4:  11000 score5:  10000 score6:  9800
# score1:  9700 score2:  6050 score3:  6550 score4:  11850 score5:  13000 score6:  9200
# score1:  9100 score2:  3650 score3:  4950 score4:  10350 score5:  7850 score6:  6600
# score1:  6700 score2:  3550 score3:  2650 score4:  13050 score5:  4300 score6:  11500
# score1:  12150 score2:  3500 score3:  3550 score4:  4500 score5:  7600 score6:  4200
# score1:  10850 score2:  4750 score3:  7050 score4:  7550 score5:  10050 score6:  10150
# score1:  8400 score2:  4150 score3:  3150 score4:  6500 score5:  12800 score6:  10350
# score1:  12250 score2:  9300 score3:  3500 score4:  5600 score5:  11150 score6:  4900
# score1:  8750 score2:  5450 score3:  7650 score4:  8300 score5:  10950 score6:  6850
# score1:  9350 score2:  5600 score3:  7600 score4:  13400 score5:  12000 score6:  9900
# score1:  10050 score2:  1350 score3:  4550 score4:  6800 score5:  7450 score6:  10000
# score1:  11000 score2:  2500 score3:  4950 score4:  4100 score5:  4750 score6:  5850
# score1:  9650 score2:  6300 score3:  4900 score4:  9400 score5:  5700 score6:  13100
# score1:  6850 score2:  6050 score3:  5600 score4:  7950 score5:  7350 score6:  10700
# score1:  3300 score2:  3400 score3:  5750 score4:  10550 score5:  5200 score6:  5950
# score1:  6400 score2:  2300 score3:  1600 score4:  3400 score5:  10500 score6:  4800
# score1:  7700 score2:  10650 score3:  10700 score4:  8800 score5:  6100 score6:  11300
# score1:  3450 score2:  3050 score3:  3400 score4:  6400 score5:  10150 score6:  6150
# score1:  9050 score2:  4200 score3:  5050 score4:  2950 score5:  1250 score6:  11550
# score1:  4150 score2:  6000 score3:  4400 score4:  10750 score5:  3850 score6:  5550
# score1:  10750 score2:  3350 score3:  3450 score4:  8550 score5:  8150 score6:  3750
# score1:  11700 score2:  4600 score3:  3650 score4:  3650 score5:  6300 score6:  6500
# score1:  10000 score2:  3350 score3:  5150 score4:  10200 score5:  8450 score6:  6350
# score1:  7300 score2:  7250 score3:  3950 score4:  10750 score5:  4900 score6:  9300
# score1:  9550 score2:  5450 score3:  4000 score4:  10350 score5:  7750 score6:  11350
# score1:  8800 score2:  4650 score3:  8150 score4:  11450 score5:  7900 score6:  10600
# score1:  9050 score2:  5550 score3:  4300 score4:  8700 score5:  12400 score6:  9900
# score1:  6900 score2:  5000 score3:  3800 score4:  3050 score5:  7050 score6:  12900
# score1:  4700 score2:  3000 score3:  2500 score4:  7000 score5:  5500 score6:  10600
# score1:  8750 score2:  2900 score3:  2700 score4:  8050 score5:  4050 score6:  10800
# score1:  5200 score2:  3150 score3:  5100 score4:  11350 score5:  8450 score6:  7450
# score1:  9450 score2:  3900 score3:  5250 score4:  8000 score5:  11850 score6:  4750
# score1:  9000 score2:  5800 score3:  5850 score4:  8050 score5:  9950 score6:  13250
# score1:  5850 score2:  5950 score3:  3400 score4:  3200 score5:  6700 score6:  10850
# score1:  7600 score2:  5300 score3:  5650 score4:  8300 score5:  10350 score6:  9050
# score1:  10100 score2:  3300 score3:  6450 score4:  6300 score5:  4000 score6:  7250
# score1:  9350 score2:  4850 score3:  5650 score4:  5050 score5:  11400 score6:  8550
# score1:  8300 score2:  5550 score3:  3900 score4:  10350 score5:  7200 score6:  10100
# score1:  11700 score2:  3000 score3:  6400 score4:  6900 score5:  7300 score6:  10750
# score1:  7050 score2:  3700 score3:  4600 score4:  3850 score5:  4850 score6:  10650
# score1:  4350 score2:  3900 score3:  2150 score4:  11100 score5:  5950 score6:  9950
# score1:  8100 score2:  3150 score3:  1450 score4:  8700 score5:  12400 score6:  3200
# score1:  5800 score2:  3400 score3:  6000 score4:  10800 score5:  7150 score6:  5050
# score1:  10500 score2:  5150 score3:  3600 score4:  5200 score5:  6100 score6:  6950
# score1:  8450 score2:  5150 score3:  1650 score4:  6900 score5:  11350 score6:  6450
# score1:  9800 score2:  5500 score3:  4950 score4:  7600 score5:  10900 score6:  9200
# score1:  10850 score2:  4250 score3:  4500 score4:  5150 score5:  6450 score6:  4900
# score1:  5100 score2:  2300 score3:  3350 score4:  2950 score5:  2200 score6:  10100
# score1:  4750 score2:  4550 score3:  3900 score4:  3600 score5:  6100 score6:  11250
# score1:  4250 score2:  3200 score3:  1650 score4:  2800 score5:  13000 score6:  3650
# score1:  12050 score2:  1150 score3:  3250 score4:  1950 score5:  8950 score6:  5200
# score1:  5100 score2:  2250 score3:  4700 score4:  4300 score5:  11500 score6:  6450
# score1:  8150 score2:  5950 score3:  8000 score4:  8200 score5:  9550 score6:  10100
# score1:  7450 score2:  9700 score3:  11500 score4:  5600 score5:  4850 score6:  9500
# score1:  8750 score2:  3900 score3:  6100 score4:  10100 score5:  2250 score6:  7950
# score1:  5400 score2:  5350 score3:  2050 score4:  10850 score5:  7700 score6:  6250
# score1:  5400 score2:  5000 score3:  5650 score4:  11550 score5:  12050 score6:  7300
# score1:  9100 score2:  3200 score3:  5150 score4:  6900 score5:  10350 score6:  7650
# score1:  8350 score2:  7700 score3:  8050 score4:  6300 score5:  10200 score6:  7050
# score1:  10650 score2:  2600 score3:  6100 score4:  9800 score5:  9550 score6:  10900
# score1:  10200 score2:  4700 score3:  1900 score4:  6200 score5:  11100 score6:  8000
# score1:  8400 score2:  8550 score3:  2600 score4:  6400 score5:  10400 score6:  6800
# score1:  10050 score2:  3700 score3:  2550 score4:  5500 score5:  8350 score6:  3950
# score1:  3450 score2:  4000 score3:  1050 score4:  10800 score5:  7200 score6:  7600
# score1:  9650 score2:  7900 score3:  4650 score4:  9850 score5:  7450 score6:  11400
# score1:  7950 score2:  5850 score3:  6200 score4:  5950 score5:  6400 score6:  10500
# score1:  11800 score2:  5400 score3:  4650 score4:  3900 score5:  3400 score6:  8100
# score1:  9400 score2:  5800 score3:  3050 score4:  7100 score5:  4850 score6:  14250
# score1:  10050 score2:  7300 score3:  5250 score4:  3400 score5:  8550 score6:  7750
# score1:  10000 score2:  2650 score3:  1050 score4:  3100 score5:  4900 score6:  5050
# score1:  5900 score2:  4850 score3:  3150 score4:  14100 score5:  7100 score6:  9650
# score1:  9150 score2:  2150 score3:  3950 score4:  10900 score5:  9550 score6:  6200
# score1:  10950 score2:  7750 score3:  4500 score4:  7050 score5:  5700 score6:  8200
# score1:  9150 score2:  3750 score3:  5650 score4:  8050 score5:  8750 score6:  11300
# score1:  11650 score2:  3800 score3:  4900 score4:  11550 score5:  6500 score6:  7850
# score1:  10150 score2:  5550 score3:  3700 score4:  8900 score5:  8050 score6:  7000
# score1:  8050 score2:  10550 score3:  3000 score4:  7750 score5:  9950 score6:  9950
# score1:  10350 score2:  2100 score3:  3600 score4:  4550 score5:  8350 score6:  7000
# score1:  11600 score2:  4250 score3:  1750 score4:  10200 score5:  6050 score6:  8600
# score1:  6200 score2:  3500 score3:  4400 score4:  6400 score5:  6700 score6:  11300
# score1:  11650 score2:  4700 score3:  3250 score4:  2250 score5:  6350 score6:  8000
# score1:  5000 score2:  4000 score3:  2150 score4:  9350 score5:  6250 score6:  14200
# score1:  4500 score2:  6450 score3:  3000 score4:  6050 score5:  6850 score6:  11650
# score1:  11550 score2:  5450 score3:  6500 score4:  8450 score5:  7400 score6:  8750
# score1:  8600 score2:  1800 score3:  3100 score4:  10450 score5:  2400 score6:  5650
# score1:  7750 score2:  6900 score3:  3700 score4:  7800 score5:  9900 score6:  11800
# score1:  10350 score2:  1650 score3:  2900 score4:  2900 score5:  3200 score6:  6300
# score1:  9900 score2:  2200 score3:  7150 score4:  8700 score5:  9000 score6:  11300
# score1:  10700 score2:  5350 score3:  4400 score4:  9200 score5:  9900 score6:  11250
# score1:  11400 score2:  3650 score3:  6400 score4:  3700 score5:  8700 score6:  6000
# score1:  7200 score2:  3300 score3:  3850 score4:  3900 score5:  12100 score6:  9800
# score1:  7000 score2:  3150 score3:  3500 score4:  4600 score5:  10500 score6:  8400
# score1:  10900 score2:  3000 score3:  3550 score4:  8550 score5:  6500 score6:  6500
# score1:  6900 score2:  3650 score3:  4400 score4:  8500 score5:  10250 score6:  11750
# score1:  10950 score2:  4500 score3:  4150 score4:  9550 score5:  4200 score6:  7900
# score1:  5000 score2:  4450 score3:  3600 score4:  2250 score5:  6800 score6:  10500
# score1:  10500 score2:  2600 score3:  5250 score4:  5050 score5:  8200 score6:  5650
# score1:  8950 score2:  4500 score3:  5900 score4:  10900 score5:  8150 score6:  9700
# score1:  9850 score2:  2350 score3:  2300 score4:  8600 score5:  4900 score6:  10500
# score1:  4250 score2:  5300 score3:  5350 score4:  10550 score5:  7400 score6:  8150
# score1:  11450 score2:  6650 score3:  6150 score4:  10950 score5:  6700 score6:  4700
# score1:  7650 score2:  4400 score3:  9000 score4:  10900 score5:  7800 score6:  11700
# score1:  6800 score2:  2850 score3:  4750 score4:  7500 score5:  7100 score6:  11150
# score1:  6750 score2:  5550 score3:  4750 score4:  10400 score5:  6050 score6:  5800
# score1:  6850 score2:  6600 score3:  5900 score4:  7100 score5:  11850 score6:  10400
# score1:  10800 score2:  3450 score3:  2350 score4:  8850 score5:  6000 score6:  11550
# score1:  4450 score2:  4950 score3:  1050 score4:  7650 score5:  13500 score6:  6100
# score1:  9800 score2:  4700 score3:  1300 score4:  10450 score5:  6250 score6:  7700
# score1:  10500 score2:  6650 score3:  3650 score4:  9700 score5:  8600 score6:  8150
# score1:  10500 score2:  2000 score3:  4900 score4:  7050 score5:  7350 score6:  7550
# score1:  9100 score2:  6750 score3:  7650 score4:  9900 score5:  9500 score6:  10150
# score1:  10300 score2:  6650 score3:  7000 score4:  8500 score5:  8150 score6:  10300
# score1:  11450 score2:  2300 score3:  5350 score4:  10650 score5:  5650 score6:  11150
# score1:  10250 score2:  4600 score3:  6950 score4:  10000 score5:  9200 score6:  6950
# score1:  2600 score2:  1100 score3:  3650 score4:  10350 score5:  2300 score6:  2350
# score1:  3650 score2:  1600 score3:  2600 score4:  6300 score5:  5450 score6:  10600
# score1:  9450 score2:  1300 score3:  3750 score4:  7800 score5:  2150 score6:  13600
# score1:  10650 score2:  6450 score3:  4900 score4:  5350 score5:  3250 score6:  6400
# score1:  6650 score2:  5800 score3:  7850 score4:  9800 score5:  7500 score6:  11100
# score1:  6700 score2:  4700 score3:  3850 score4:  11750 score5:  9500 score6:  6850
# score1:  3750 score2:  5550 score3:  2600 score4:  3600 score5:  3200 score6:  11950
# score1:  10800 score2:  4100 score3:  9800 score4:  9100 score5:  10050 score6:  9850
# score1:  5400 score2:  5600 score3:  1600 score4:  8100 score5:  8100 score6:  10850
# score1:  10000 score2:  1550 score3:  5550 score4:  7400 score5:  8250 score6:  4800
# score1:  7550 score2:  6050 score3:  5350 score4:  9700 score5:  7750 score6:  10750
# score1:  11950 score2:  5600 score3:  2900 score4:  7750 score5:  2850 score6:  9650
# score1:  8050 score2:  5400 score3:  9500 score4:  12100 score5:  8700 score6:  7050
# score1:  11050 score2:  3850 score3:  5050 score4:  5100 score5:  3050 score6:  4450
# score1:  7350 score2:  3700 score3:  2850 score4:  5350 score5:  4700 score6:  10500
# score1:  11250 score2:  4150 score3:  3200 score4:  9950 score5:  7600 score6:  10250
# score1:  10300 score2:  4700 score3:  5300 score4:  5950 score5:  6700 score6:  6300
# score1:  11200 score2:  6300 score3:  9300 score4:  5050 score5:  7150 score6:  7650
# score1:  10550 score2:  4650 score3:  3550 score4:  3600 score5:  6550 score6:  6050
# score1:  9050 score2:  7350 score3:  5750 score4:  9150 score5:  11300 score6:  5900
# score1:  7250 score2:  7650 score3:  4750 score4:  9100 score5:  11000 score6:  11550
# score1:  10100 score2:  2950 score3:  3300 score4:  5300 score5:  7300 score6:  6300
# score1:  7900 score2:  5400 score3:  4750 score4:  11200 score5:  6550 score6:  8050
# score1:  12350 score2:  5700 score3:  4850 score4:  8750 score5:  7800 score6:  8750
# score1:  4950 score2:  2900 score3:  5700 score4:  2200 score5:  10900 score6:  10350
# score1:  5450 score2:  2650 score3:  2000 score4:  10050 score5:  6700 score6:  8000
# score1:  8200 score2:  4100 score3:  5050 score4:  8700 score5:  5900 score6:  10000
# score1:  12150 score2:  5700 score3:  6950 score4:  8450 score5:  8750 score6:  7350
# score1:  7750 score2:  7500 score3:  7250 score4:  10200 score5:  8050 score6:  11150
# score1:  7750 score2:  3300 score3:  4500 score4:  10500 score5:  11800 score6:  6600
# score1:  10350 score2:  3700 score3:  5050 score4:  10000 score5:  10350 score6:  8600
# score1:  8400 score2:  6350 score3:  5550 score4:  9550 score5:  9800 score6:  11200
# score1:  10900 score2:  4600 score3:  8000 score4:  9000 score5:  9300 score6:  6450
# score1:  11650 score2:  3750 score3:  3300 score4:  6800 score5:  9300 score6:  9200
# score1:  8750 score2:  4950 score3:  3650 score4:  8000 score5:  15800 score6:  4250
# score1:  3900 score2:  1150 score3:  3500 score4:  10450 score5:  7600 score6:  5900
# score1:  4700 score2:  3300 score3:  5650 score4:  8600 score5:  9600 score6:  10950
# score1:  7300 score2:  6750 score3:  7250 score4:  8700 score5:  10800 score6:  4750
# score1:  10650 score2:  5250 score3:  7100 score4:  10000 score5:  9550 score6:  10550
# score1:  11650 score2:  3200 score3:  6700 score4:  11250 score5:  5100 score6:  4500
# score1:  11350 score2:  3950 score3:  7550 score4:  3950 score5:  5200 score6:  7800
# score1:  10450 score2:  5950 score3:  4550 score4:  10250 score5:  8800 score6:  9950
# score1:  7700 score2:  5350 score3:  3800 score4:  10300 score5:  5050 score6:  6650
# score1:  6350 score2:  11150 score3:  5600 score4:  5500 score5:  6950 score6:  12450
# score1:  11300 score2:  6300 score3:  650 score4:  6650 score5:  3250 score6:  6250
# score1:  13350 score2:  5000 score3:  6300 score4:  4950 score5:  8850 score6:  5950
# score1:  12200 score2:  5850 score3:  4850 score4:  9450 score5:  3800 score6:  7900
# score1:  10500 score2:  5600 score3:  8150 score4:  9350 score5:  10850 score6:  8700
# score1:  3500 score2:  4500 score3:  3350 score4:  5800 score5:  11750 score6:  5750
# score1:  8100 score2:  5750 score3:  7700 score4:  8800 score5:  11250 score6:  8250
# score1:  9400 score2:  4250 score3:  6900 score4:  11000 score5:  10000 score6:  8650
# score1:  7750 score2:  7900 score3:  4400 score4:  10250 score5:  10000 score6:  5950
# score1:  3900 score2:  3350 score3:  2750 score4:  1500 score5:  3450 score6:  12200
# score1:  7350 score2:  6800 score3:  4900 score4:  10600 score5:  7450 score6:  8400
# score1:  9450 score2:  5100 score3:  3150 score4:  11300 score5:  6150 score6:  10450
# score1:  2500 score2:  2600 score3:  2800 score4:  6950 score5:  7250 score6:  10500
# score1:  12400 score2:  3400 score3:  2450 score4:  6500 score5:  4100 score6:  4550
# score1:  8400 score2:  5200 score3:  7200 score4:  8700 score5:  10200 score6:  6100
# score1:  6750 score2:  5900 score3:  6550 score4:  6950 score5:  9450 score6:  12900
# score1:  10600 score2:  4200 score3:  4100 score4:  7750 score5:  10250 score6:  6250
# score1:  5950 score2:  4800 score3:  6000 score4:  6050 score5:  10550 score6:  10600
# score1:  7100 score2:  10100 score3:  6050 score4:  10450 score5:  11400 score6:  10100
# score1:  7550 score2:  6500 score3:  7000 score4:  7700 score5:  9750 score6:  10700
# score1:  10850 score2:  5400 score3:  3100 score4:  8800 score5:  7900 score6:  3450
# score1:  7350 score2:  3450 score3:  4000 score4:  4850 score5:  10400 score6:  3500
# score1:  11550 score2:  5650 score3:  3250 score4:  13250 score5:  8850 score6:  8150
# score1:  9050 score2:  4450 score3:  5200 score4:  7850 score5:  4600 score6:  11400
# score1:  1600 score2:  2900 score3:  5400 score4:  5750 score5:  10900 score6:  5850
# score1:  11450 score2:  7650 score3:  6950 score4:  4150 score5:  5100 score6:  9850
# score1:  8400 score2:  5950 score3:  3500 score4:  9450 score5:  8300 score6:  10550
# score1:  8500 score2:  3850 score3:  6550 score4:  7800 score5:  9500 score6:  10150
# score1:  5050 score2:  6250 score3:  3200 score4:  5700 score5:  6800 score6:  10850
# score1:  11300 score2:  7250 score3:  6900 score4:  9900 score5:  9150 score6:  9950
# score1:  4950 score2:  3200 score3:  3950 score4:  6550 score5:  6500 score6:  13700
# score1:  9650 score2:  8350 score3:  5550 score4:  8950 score5:  10700 score6:  13200
# score1:  8850 score2:  4050 score3:  6400 score4:  8350 score5:  11000 score6:  6300
# score1:  7550 score2:  4950 score3:  3600 score4:  6350 score5:  6300 score6:  13150
# score1:  4700 score2:  3400 score3:  1650 score4:  7600 score5:  5750 score6:  12700
# score1:  8200 score2:  2600 score3:  1550 score4:  6950 score5:  4500 score6:  11150
# score1:  4350 score2:  2500 score3:  5350 score4:  10850 score5:  7100 score6:  8400
# score1:  7500 score2:  4650 score3:  1050 score4:  11100 score5:  5050 score6:  5100
# score1:  7050 score2:  9450 score3:  3900 score4:  3600 score5:  6400 score6:  10250
# score1:  11200 score2:  6100 score3:  7600 score4:  9150 score5:  9900 score6:  9100
# score1:  7200 score2:  8950 score3:  5200 score4:  8750 score5:  10600 score6:  7500
# score1:  6600 score2:  5800 score3:  1050 score4:  4300 score5:  10550 score6:  2500
# score1:  5050 score2:  3550 score3:  2650 score4:  6600 score5:  10050 score6:  5550
# score1:  10650 score2:  5100 score3:  1100 score4:  9450 score5:  11450 score6:  7600
# score1:  10500 score2:  4950 score3:  7400 score4:  5150 score5:  10700 score6:  10100
# score1:  5250 score2:  2150 score3:  5900 score4:  3250 score5:  10800 score6:  5650
# score1:  3450 score2:  5300 score3:  6400 score4:  11900 score5:  6450 score6:  9350
# score1:  9750 score2:  4050 score3:  5800 score4:  12900 score5:  6250 score6:  6250
# score1:  11100 score2:  3450 score3:  4600 score4:  6600 score5:  7800 score6:  7500
# score1:  10650 score2:  4100 score3:  4100 score4:  4500 score5:  5500 score6:  4000
# score1:  5000 score2:  4750 score3:  2050 score4:  10950 score5:  4750 score6:  5750
# score1:  9150 score2:  3150 score3:  4200 score4:  9200 score5:  11950 score6:  6000
# score1:  9550 score2:  4300 score3:  3300 score4:  10450 score5:  6100 score6:  11100
# score1:  7000 score2:  4450 score3:  8650 score4:  9250 score5:  7300 score6:  10850
# score1:  8200 score2:  7200 score3:  7700 score4:  10200 score5:  6600 score6:  9200
# score1:  13950 score2:  3150 score3:  2650 score4:  9250 score5:  9950 score6:  5500
# score1:  11150 score2:  6500 score3:  6150 score4:  7400 score5:  8950 score6:  10450
# score1:  3400 score2:  4050 score3:  2500 score4:  2700 score5:  12350 score6:  8350
# score1:  9900 score2:  4550 score3:  5600 score4:  10300 score5:  9150 score6:  10900
# score1:  7050 score2:  3200 score3:  2700 score4:  3600 score5:  6350 score6:  10050
# score1:  4450 score2:  8600 score3:  4300 score4:  10750 score5:  7150 score6:  9000
# score1:  10000 score2:  1500 score3:  750 score4:  3300 score5:  4750 score6:  10600
# score1:  7900 score2:  4950 score3:  2550 score4:  11300 score5:  1200 score6:  6500
# score1:  600 score2:  1850 score3:  1750 score4:  6250 score5:  13750 score6:  8850
# score1:  11600 score2:  4350 score3:  2600 score4:  7150 score5:  10050 score6:  4650
# score1:  9700 score2:  6700 score3:  4850 score4:  9950 score5:  5950 score6:  10750
# score1:  8450 score2:  5950 score3:  7300 score4:  6300 score5:  10950 score6:  7550
# score1:  8000 score2:  1650 score3:  7500 score4:  9300 score5:  2750 score6:  11650
# score1:  7200 score2:  3750 score3:  5550 score4:  6750 score5:  11250 score6:  6250
# score1:  10700 score2:  10450 score3:  2900 score4:  8400 score5:  8850 score6:  9000
# score1:  4650 score2:  5750 score3:  8350 score4:  6850 score5:  10700 score6:  10800
# score1:  4150 score2:  5600 score3:  1950 score4:  10150 score5:  8150 score6:  8000
# score1:  10050 score2:  5450 score3:  3100 score4:  7500 score5:  10350 score6:  3600
# score1:  7450 score2:  5050 score3:  7350 score4:  10300 score5:  8100 score6:  6650
# score1:  10300 score2:  1900 score3:  3150 score4:  2500 score5:  4400 score6:  5500
# score1:  9950 score2:  3950 score3:  3800 score4:  12900 score5:  8500 score6:  6600
# score1:  2700 score2:  2050 score3:  500 score4:  11150 score5:  3300 score6:  3850
# score1:  2100 score2:  2600 score3:  3900 score4:  5600 score5:  8450 score6:  11250
# score1:  8200 score2:  6150 score3:  2850 score4:  6800 score5:  10100 score6:  4300
# score1:  11200 score2:  6100 score3:  3450 score4:  6200 score5:  6850 score6:  9200
# score1:  12200 score2:  2100 score3:  3500 score4:  1600 score5:  5200 score6:  4100
# score1:  13650 score2:  6600 score3:  5100 score4:  6950 score5:  10300 score6:  11450
# score1:  6550 score2:  2500 score3:  3650 score4:  10750 score5:  8700 score6:  8850
# score1:  9050 score2:  6300 score3:  3100 score4:  5450 score5:  11650 score6:  7000
# score1:  4200 score2:  5750 score3:  2850 score4:  5250 score5:  10950 score6:  3150
# score1:  10300 score2:  3350 score3:  3800 score4:  7550 score5:  5700 score6:  5350
# score1:  9650 score2:  4000 score3:  6800 score4:  1400 score5:  10450 score6:  4250
# score1:  9300 score2:  5700 score3:  3900 score4:  8600 score5:  12400 score6:  4750
# score1:  10550 score2:  2800 score3:  4650 score4:  4400 score5:  9900 score6:  3400
# score1:  11900 score2:  5650 score3:  4750 score4:  10100 score5:  10350 score6:  4600
# score1:  4750 score2:  4800 score3:  7100 score4:  13500 score5:  7850 score6:  4000
# score1:  10450 score2:  2650 score3:  7000 score4:  10450 score5:  4100 score6:  6900
# score1:  5250 score2:  3550 score3:  3750 score4:  10350 score5:  8350 score6:  5850
# score1:  13150 score2:  7100 score3:  7250 score4:  9900 score5:  8950 score6:  6700
# score1:  10700 score2:  5600 score3:  7300 score4:  7000 score5:  11850 score6:  10600
# score1:  10550 score2:  3800 score3:  6600 score4:  6850 score5:  1200 score6:  8150
# score1:  5450 score2:  1100 score3:  650 score4:  6900 score5:  7450 score6:  11250
# score1:  8950 score2:  2300 score3:  2700 score4:  5250 score5:  9400 score6:  10250
# score1:  8750 score2:  2150 score3:  6400 score4:  10750 score5:  6200 score6:  7400
# score1:  12350 score2:  3550 score3:  6850 score4:  5700 score5:  6500 score6:  9500
# score1:  6600 score2:  2000 score3:  3100 score4:  5550 score5:  2300 score6:  10450
# score1:  10600 score2:  5350 score3:  3850 score4:  9450 score5:  10500 score6:  7700
# score1:  2150 score2:  5200 score3:  1100 score4:  11400 score5:  2750 score6:  4000
# score1:  8650 score2:  3600 score3:  2150 score4:  10700 score5:  9600 score6:  6550
# score1:  10200 score2:  3700 score3:  4300 score4:  11350 score5:  5950 score6:  5200
# score1:  9250 score2:  3300 score3:  7750 score4:  10600 score5:  8500 score6:  10200
# score1:  7450 score2:  2650 score3:  2900 score4:  10250 score5:  11000 score6:  1700
# score1:  5650 score2:  5200 score3:  5150 score4:  15050 score5:  7100 score6:  6900
# score1:  3950 score2:  2850 score3:  4100 score4:  10000 score5:  6100 score6:  8500
# score1:  11350 score2:  4800 score3:  7550 score4:  4000 score5:  9800 score6:  5550
# score1:  8150 score2:  1050 score3:  4400 score4:  7150 score5:  12000 score6:  5750
# score1:  7050 score2:  2500 score3:  3150 score4:  11200 score5:  8150 score6:  10200
# score1:  11250 score2:  600 score3:  2700 score4:  5600 score5:  11250 score6:  7350
# score1:  3750 score2:  9350 score3:  4900 score4:  8350 score5:  10700 score6:  7300
# score1:  5300 score2:  6000 score3:  3000 score4:  6800 score5:  5750 score6:  10100
# score1:  7450 score2:  5250 score3:  3600 score4:  4350 score5:  8300 score6:  10550
# score1:  9300 score2:  6200 score3:  3600 score4:  7500 score5:  8150 score6:  11700
# score1:  9100 score2:  7050 score3:  4950 score4:  10650 score5:  10350 score6:  11900
# score1:  6250 score2:  1850 score3:  3150 score4:  6900 score5:  3400 score6:  10300
# score1:  8550 score2:  6350 score3:  7100 score4:  4850 score5:  10300 score6:  7800
# score1:  9600 score2:  5350 score3:  4600 score4:  3250 score5:  10650 score6:  8250
# score1:  7500 score2:  2600 score3:  6200 score4:  7550 score5:  10750 score6:  7950
# score1:  6000 score2:  5400 score3:  9800 score4:  6750 score5:  6650 score6:  10550
# score1:  9250 score2:  2050 score3:  2650 score4:  5050 score5:  7900 score6:  11400
# score1:  10550 score2:  5250 score3:  2750 score4:  7900 score5:  8200 score6:  5650
# score1:  8900 score2:  2250 score3:  5050 score4:  7950 score5:  7300 score6:  12300
# score1:  1550 score2:  3400 score3:  2300 score4:  11150 score5:  6250 score6:  9650
# score1:  1350 score2:  1000 score3:  2050 score4:  3550 score5:  6000 score6:  10700
# score1:  6650 score2:  7000 score3:  8500 score4:  9000 score5:  7150 score6:  12900
# score1:  3600 score2:  6150 score3:  5950 score4:  10350 score5:  7550 score6:  11200
# score1:  10800 score2:  4700 score3:  6250 score4:  6900 score5:  4050 score6:  5550
# score1:  7650 score2:  7600 score3:  3000 score4:  4600 score5:  11150 score6:  5750
# score1:  13050 score2:  4600 score3:  3650 score4:  8450 score5:  8850 score6:  7800
# score1:  7600 score2:  2950 score3:  1200 score4:  11550 score5:  8100 score6:  8400
# score1:  10850 score2:  4300 score3:  2300 score4:  14400 score5:  2950 score6:  7150
# score1:  5650 score2:  4700 score3:  5550 score4:  6500 score5:  8150 score6:  10200
# score1:  9200 score2:  6550 score3:  4400 score4:  7900 score5:  11550 score6:  7500
# score1:  8300 score2:  5950 score3:  5400 score4:  10700 score5:  8000 score6:  9900
# score1:  5050 score2:  2350 score3:  3400 score4:  4100 score5:  7150 score6:  11050
# score1:  9250 score2:  6900 score3:  6950 score4:  8400 score5:  12250 score6:  10200
# score1:  10750 score2:  2900 score3:  3550 score4:  5200 score5:  9450 score6:  3700
# score1:  8700 score2:  4500 score3:  7650 score4:  9750 score5:  10400 score6:  10750
# score1:  10250 score2:  5850 score3:  4250 score4:  8250 score5:  12150 score6:  8550
# score1:  11050 score2:  3900 score3:  8850 score4:  8900 score5:  8950 score6:  7950
# score1:  6000 score2:  8400 score3:  5650 score4:  6350 score5:  9400 score6:  10950
# score1:  5600 score2:  5350 score3:  5500 score4:  10500 score5:  8400 score6:  6200
# score1:  10000 score2:  4400 score3:  6900 score4:  5300 score5:  7900 score6:  10750
# score1:  11250 score2:  1500 score3:  2600 score4:  6550 score5:  4250 score6:  6300
# score1:  6700 score2:  4500 score3:  3150 score4:  7000 score5:  10200 score6:  5950
# score1:  5700 score2:  3850 score3:  4950 score4:  5300 score5:  8450 score6:  12650
# score1:  6350 score2:  6100 score3:  6850 score4:  9000 score5:  10150 score6:  6900
# score1:  8400 score2:  2650 score3:  8100 score4:  12200 score5:  8600 score6:  6850
# score1:  7200 score2:  4300 score3:  2700 score4:  8500 score5:  11050 score6:  7100
# score1:  12600 score2:  6050 score3:  7000 score4:  7500 score5:  6550 score6:  8550
# score1:  7350 score2:  6050 score3:  7750 score4:  10200 score5:  13200 score6:  8500
# score1:  4350 score2:  5950 score3:  5150 score4:  13850 score5:  8550 score6:  12100
# score1:  8650 score2:  4650 score3:  4450 score4:  6650 score5:  6650 score6:  11650
# score1:  9650 score2:  7150 score3:  4900 score4:  14500 score5:  8500 score6:  6650
# score1:  5000 score2:  1100 score3:  2850 score4:  4200 score5:  10900 score6:  2650
# score1:  850 score2:  5400 score3:  1050 score4:  6400 score5:  7550 score6:  10750
# score1:  12350 score2:  2400 score3:  6050 score4:  8250 score5:  8600 score6:  4800
# score1:  1200 score2:  4400 score3:  5300 score4:  11700 score5:  7750 score6:  2850
# score1:  8800 score2:  5800 score3:  4350 score4:  7550 score5:  11500 score6:  7850
# score1:  6700 score2:  7000 score3:  6850 score4:  7050 score5:  7050 score6:  11700
# score1:  5400 score2:  4100 score3:  4150 score4:  7100 score5:  11600 score6:  4500
# score1:  9500 score2:  5200 score3:  8150 score4:  8150 score5:  9500 score6:  11200
# score1:  10600 score2:  4500 score3:  7050 score4:  15150 score5:  5350 score6:  8350
# score1:  7850 score2:  6450 score3:  4900 score4:  13400 score5:  3200 score6:  10950
# score1:  10050 score2:  4150 score3:  2300 score4:  6700 score5:  4600 score6:  3200
# score1:  8050 score2:  3800 score3:  6350 score4:  9300 score5:  10300 score6:  9750
# score1:  7800 score2:  3850 score3:  3550 score4:  2250 score5:  9650 score6:  10350
# score1:  9750 score2:  3100 score3:  5600 score4:  8050 score5:  7150 score6:  10600
# score1:  6700 score2:  5400 score3:  6200 score4:  12000 score5:  4550 score6:  10150
# score1:  12500 score2:  2650 score3:  5000 score4:  3950 score5:  4600 score6:  4350
# score1:  11850 score2:  5200 score3:  6750 score4:  5350 score5:  10250 score6:  4500
# score1:  5050 score2:  6400 score3:  5150 score4:  5200 score5:  5400 score6:  13550
# score1:  10200 score2:  4150 score3:  4250 score4:  9550 score5:  6800 score6:  3250
# score1:  10950 score2:  4850 score3:  6300 score4:  5550 score5:  7450 score6:  5750
# score1:  12800 score2:  2200 score3:  3800 score4:  7950 score5:  9750 score6:  7700
# score1:  10300 score2:  4600 score3:  6700 score4:  6600 score5:  10050 score6:  11450
# score1:  11850 score2:  2400 score3:  4700 score4:  4400 score5:  3050 score6:  3600
# score1:  8750 score2:  6900 score3:  3400 score4:  8850 score5:  4800 score6:  11050
# score1:  9400 score2:  5050 score3:  3200 score4:  11600 score5:  7750 score6:  11450
# score1:  6550 score2:  7300 score3:  3750 score4:  10300 score5:  6000 score6:  3750
# score1:  6850 score2:  2250 score3:  1900 score4:  12400 score5:  6800 score6:  8900
# score1:  12000 score2:  3200 score3:  2350 score4:  6400 score5:  3500 score6:  6300
# score1:  11300 score2:  3350 score3:  6250 score4:  7800 score5:  7700 score6:  10150
# score1:  13050 score2:  5200 score3:  3400 score4:  6850 score5:  6250 score6:  5250
# score1:  6700 score2:  4650 score3:  3500 score4:  10150 score5:  4850 score6:  4550
# score1:  10250 score2:  5950 score3:  3850 score4:  7000 score5:  4100 score6:  8200
# score1:  10950 score2:  1550 score3:  3200 score4:  3900 score5:  7200 score6:  5400
# score1:  10750 score2:  3200 score3:  5650 score4:  6200 score5:  6500 score6:  6950
# score1:  5100 score2:  7350 score3:  6850 score4:  4750 score5:  12550 score6:  7300
# score1:  4200 score2:  3700 score3:  5900 score4:  8750 score5:  4850 score6:  11550
# score1:  6650 score2:  2750 score3:  2550 score4:  4750 score5:  5350 score6:  12500
# score1:  9550 score2:  6350 score3:  4300 score4:  9150 score5:  4300 score6:  11100
# score1:  8400 score2:  5550 score3:  6200 score4:  3850 score5:  11550 score6:  8100
# score1:  8450 score2:  4000 score3:  4150 score4:  10750 score5:  4400 score6:  7900
# score1:  10550 score2:  4400 score3:  4800 score4:  8200 score5:  7800 score6:  9200
# score1:  6850 score2:  3400 score3:  4450 score4:  11600 score5:  14000 score6:  10400
# score1:  5250 score2:  1250 score3:  5900 score4:  5700 score5:  10450 score6:  7850
# score1:  5650 score2:  3650 score3:  5000 score4:  4800 score5:  11450 score6:  3550
# score1:  12000 score2:  2650 score3:  2500 score4:  5100 score5:  5350 score6:  5050
# score1:  12300 score2:  1250 score3:  7350 score4:  10000 score5:  10500 score6:  6950
# score1:  10250 score2:  1150 score3:  5100 score4:  3900 score5:  6200 score6:  4900
# score1:  10250 score2:  3600 score3:  4600 score4:  7850 score5:  3900 score6:  9250
# score1:  5650 score2:  5100 score3:  2550 score4:  5400 score5:  9250 score6:  10150
# score1:  10500 score2:  3400 score3:  2100 score4:  8600 score5:  8800 score6:  11550
# score1:  8000 score2:  2800 score3:  6200 score4:  5600 score5:  11000 score6:  7600
# score1:  8200 score2:  3550 score3:  5350 score4:  10150 score5:  2350 score6:  9100
# score1:  11100 score2:  1900 score3:  3100 score4:  8600 score5:  7800 score6:  10150
# score1:  10100 score2:  4350 score3:  5350 score4:  8750 score5:  8550 score6:  7050
# score1:  13050 score2:  4900 score3:  7250 score4:  10100 score5:  6550 score6:  5050
# score1:  4100 score2:  1300 score3:  2650 score4:  6950 score5:  10750 score6:  6150
# score1:  11350 score2:  7650 score3:  5750 score4:  5200 score5:  7900 score6:  5450
# score1:  9850 score2:  4200 score3:  5450 score4:  11100 score5:  1150 score6:  3950
# score1:  6650 score2:  8400 score3:  5400 score4:  14450 score5:  9650 score6:  9050
# score1:  8100 score2:  7100 score3:  3350 score4:  3150 score5:  4900 score6:  10950
# score1:  11600 score2:  5150 score3:  4350 score4:  7850 score5:  7650 score6:  4900
# score1:  6500 score2:  4050 score3:  5200 score4:  4600 score5:  3650 score6:  12100
# score1:  10850 score2:  8100 score3:  4150 score4:  6900 score5:  7850 score6:  8850
# score1:  4400 score2:  4050 score3:  2000 score4:  11500 score5:  8600 score6:  7200
# score1:  7150 score2:  4650 score3:  5150 score4:  10300 score5:  5900 score6:  1550
# score1:  13200 score2:  4200 score3:  3450 score4:  6950 score5:  3050 score6:  3850
# score1:  9250 score2:  7850 score3:  5750 score4:  10150 score5:  9150 score6:  9300
# score1:  7450 score2:  1650 score3:  5300 score4:  10550 score5:  3600 score6:  5100
# score1:  12950 score2:  4400 score3:  2850 score4:  4350 score5:  4200 score6:  6200
# score1:  4700 score2:  3750 score3:  4700 score4:  11650 score5:  3500 score6:  6700
# score1:  6400 score2:  3950 score3:  3400 score4:  7800 score5:  7150 score6:  10600
# score1:  5350 score2:  6350 score3:  4650 score4:  9300 score5:  12000 score6:  5050
# score1:  11350 score2:  3850 score3:  1100 score4:  4100 score5:  9150 score6:  8900
# score1:  5500 score2:  4450 score3:  4600 score4:  5900 score5:  5600 score6:  11900
# score1:  4650 score2:  2350 score3:  5700 score4:  12200 score5:  4550 score6:  6650
# score1:  7200 score2:  6700 score3:  4800 score4:  11150 score5:  7500 score6:  8650
# score1:  12350 score2:  1600 score3:  0 score4:  3650 score5:  1050 score6:  3150
# score1:  6200 score2:  5300 score3:  6200 score4:  10000 score5:  7950 score6:  6450
# score1:  8150 score2:  2400 score3:  3250 score4:  10900 score5:  7300 score6:  10100
# score1:  10850 score2:  2050 score3:  2750 score4:  6150 score5:  2750 score6:  3700
# score1:  10900 score2:  2550 score3:  2150 score4:  5200 score5:  5150 score6:  3700
# score1:  10400 score2:  7750 score3:  6000 score4:  10300 score5:  9700 score6:  8200
# score1:  4900 score2:  5700 score3:  3000 score4:  4650 score5:  10850 score6:  4600
# score1:  7350 score2:  3900 score3:  5250 score4:  8800 score5:  13200 score6:  7700
# score1:  10000 score2:  3850 score3:  7000 score4:  5100 score5:  6100 score6:  5500
# score1:  6750 score2:  3400 score3:  4250 score4:  10300 score5:  7600 score6:  4550
# score1:  11250 score2:  5200 score3:  4850 score4:  8300 score5:  6950 score6:  7900
# score1:  9250 score2:  5200 score3:  4350 score4:  13000 score5:  7000 score6:  9000
# score1:  11850 score2:  3800 score3:  3000 score4:  4400 score5:  4350 score6:  6150
# score1:  5600 score2:  5750 score3:  4300 score4:  9850 score5:  6600 score6:  12400
# score1:  12100 score2:  2700 score3:  5800 score4:  6000 score5:  9550 score6:  9200
# score1:  5850 score2:  3000 score3:  4450 score4:  11700 score5:  4300 score6:  7950
# score1:  6800 score2:  1000 score3:  5100 score4:  4500 score5:  11450 score6:  5000
# score1:  3650 score2:  6150 score3:  5100 score4:  5800 score5:  10650 score6:  9900
# score1:  7350 score2:  1500 score3:  5350 score4:  11600 score5:  7700 score6:  3600
# score1:  10800 score2:  3800 score3:  5000 score4:  5400 score5:  8050 score6:  6850
# score1:  5650 score2:  4150 score3:  4300 score4:  5750 score5:  11150 score6:  7350
# score1:  8500 score2:  6250 score3:  4250 score4:  5500 score5:  6150 score6:  10050
# score1:  11550 score2:  2800 score3:  3300 score4:  7100 score5:  4800 score6:  6650
# score1:  8100 score2:  7400 score3:  5700 score4:  7750 score5:  4850 score6:  10650
# score1:  7950 score2:  4500 score3:  2650 score4:  6850 score5:  5250 score6:  11500
# score1:  10750 score2:  2200 score3:  1400 score4:  5350 score5:  3750 score6:  4150
# score1:  6000 score2:  3050 score3:  3700 score4:  4950 score5:  7750 score6:  10800
# score1:  9900 score2:  3500 score3:  2750 score4:  11050 score5:  7000 score6:  7750
# score1:  8350 score2:  7250 score3:  5950 score4:  8750 score5:  6950 score6:  10500
# score1:  10400 score2:  2850 score3:  5000 score4:  6300 score5:  3450 score6:  7650
# score1:  6000 score2:  2150 score3:  3500 score4:  4600 score5:  10200 score6:  5600
# score1:  5800 score2:  5550 score3:  6600 score4:  7500 score5:  10400 score6:  6000
# score1:  9000 score2:  7850 score3:  6350 score4:  10450 score5:  8900 score6:  10900
# score1:  6050 score2:  4200 score3:  8000 score4:  4850 score5:  11150 score6:  10400
# score1:  12100 score2:  5300 score3:  7550 score4:  8950 score5:  8650 score6:  5250
# score1:  11700 score2:  4650 score3:  2350 score4:  4250 score5:  1200 score6:  6150
# score1:  13050 score2:  2000 score3:  2050 score4:  6700 score5:  5050 score6:  3150
# score1:  9050 score2:  6950 score3:  1700 score4:  12400 score5:  6400 score6:  10950
# score1:  12350 score2:  5000 score3:  6950 score4:  10750 score5:  8950 score6:  9500
# score1:  11200 score2:  1250 score3:  2450 score4:  6400 score5:  4600 score6:  7100
# score1:  10950 score2:  2150 score3:  4500 score4:  6450 score5:  6100 score6:  8300
# score1:  6600 score2:  3050 score3:  2300 score4:  9700 score5:  10650 score6:  7150
# score1:  6050 score2:  8450 score3:  5650 score4:  13900 score5:  9100 score6:  9750
# score1:  5400 score2:  6300 score3:  7000 score4:  6000 score5:  11750 score6:  5950
# score1:  7200 score2:  4500 score3:  5350 score4:  10000 score5:  7200 score6:  5900
# score1:  4600 score2:  5850 score3:  3850 score4:  8750 score5:  10650 score6:  10950
# score1:  10250 score2:  4950 score3:  4050 score4:  8700 score5:  6750 score6:  7400
# score1:  9400 score2:  6500 score3:  5450 score4:  10100 score5:  8750 score6:  7500
# score1:  6450 score2:  7150 score3:  6350 score4:  12800 score5:  9000 score6:  6550
# score1:  3750 score2:  5350 score3:  7950 score4:  9350 score5:  9950 score6:  10000
# score1:  10950 score2:  5850 score3:  3700 score4:  5250 score5:  6750 score6:  5150
# score1:  11000 score2:  4850 score3:  4900 score4:  5850 score5:  10000 score6:  8400
# score1:  8150 score2:  3400 score3:  7900 score4:  12800 score5:  8100 score6:  9450
# score1:  5800 score2:  1900 score3:  3600 score4:  4450 score5:  10250 score6:  2350
# score1:  10250 score2:  1800 score3:  2200 score4:  7550 score5:  14850 score6:  6900
# score1:  8400 score2:  3050 score3:  2300 score4:  10350 score5:  10600 score6:  10050
# score1:  5450 score2:  1450 score3:  4150 score4:  11450 score5:  6000 score6:  8000
# score1:  9300 score2:  1850 score3:  6000 score4:  10150 score5:  4350 score6:  4700
# score1:  8650 score2:  2100 score3:  0 score4:  4400 score5:  12700 score6:  5900
# score1:  10950 score2:  4900 score3:  3650 score4:  7800 score5:  11700 score6:  9950
# score1:  11450 score2:  2700 score3:  2900 score4:  3350 score5:  5300 score6:  2300
# score1:  10350 score2:  5700 score3:  5750 score4:  13350 score5:  4600 score6:  8450
# score1:  5650 score2:  6250 score3:  4300 score4:  10850 score5:  7450 score6:  12450
# score1:  7300 score2:  3600 score3:  5450 score4:  6500 score5:  5050 score6:  12200
# score1:  13200 score2:  7550 score3:  3700 score4:  9400 score5:  3950 score6:  5250
# score1:  11550 score2:  5500 score3:  1600 score4:  2350 score5:  6250 score6:  6400
# score1:  12650 score2:  3750 score3:  6000 score4:  10000 score5:  5900 score6:  9500
# score1:  1050 score2:  1000 score3:  650 score4:  4200 score5:  10300 score6:  1200
# score1:  10100 score2:  1500 score3:  5650 score4:  8950 score5:  5100 score6:  5700
# score1:  7950 score2:  3200 score3:  2650 score4:  10300 score5:  10100 score6:  7200
# score1:  7000 score2:  3500 score3:  3250 score4:  3850 score5:  5950 score6:  10000
# score1:  5800 score2:  3450 score3:  3950 score4:  6300 score5:  5250 score6:  10450
# score1:  2850 score2:  1600 score3:  3850 score4:  5050 score5:  6250 score6:  11750
# score1:  8750 score2:  5900 score3:  4450 score4:  7900 score5:  5950 score6:  10200
# score1:  5900 score2:  5700 score3:  4200 score4:  10250 score5:  8300 score6:  4550
# score1:  10500 score2:  5550 score3:  4650 score4:  10800 score5:  5900 score6:  7700
# score1:  4000 score2:  7700 score3:  3850 score4:  11300 score5:  6900 score6:  4950
# score1:  3500 score2:  5150 score3:  4800 score4:  9300 score5:  8000 score6:  10050
# score1:  7600 score2:  4250 score3:  5700 score4:  9050 score5:  10300 score6:  8950
# score1:  3150 score2:  5900 score3:  2350 score4:  5050 score5:  6000 score6:  10900
# ...
# score1:  6450 score2:  2550 score3:  5100 score4:  11500 score5:  5800 score6:  6500
# score1:  12400 score2:  6900 score3:  8450 score4:  5850 score5:  5450 score6:  9350
# score1:  7750 score2:  2950 score3:  4250 score4:  12700 score5:  7900 score6:  7050
# score1:  8350 score2:  7950 score3:  1700 score4:  8400 score5:  7450 score6:  12100
# score1:  10450 score2:  6200 score3:  4250 score4:  10400 score5:  4900 score6:  9850
# score1:  6250 score2:  2750 score3:  3800 score4:  6600 score5:  14050 score6:  3050
# score1:  7800 score2:  2850 score3:  5200 score4:  10600 score5:  5700 score6:  8250
# score1:  3050 score2:  3700 score3:  2150 score4:  11250 score5:  6800 score6:  4850
# score1:  5850 score2:  2750 score3:  10100 score4:  10850 score5:  7950 score6:  9500
# score1:  10100 score2:  2500 score3:  4150 score4:  6400 score5:  1200 score6:  2750
# score1:  11000 score2:  4150 score3:  1650 score4:  7300 score5:  5150 score6:  6400
# score1:  10350 score2:  3500 score3:  5550 score4:  8400 score5:  9900 score6:  4150
# score1:  4300 score2:  6700 score3:  2750 score4:  10800 score5:  8250 score6:  12750
# score1:  11350 score2:  3150 score3:  3350 score4:  6900 score5:  6350 score6:  4250
# score1:  3900 score2:  3900 score3:  1550 score4:  3700 score5:  12850 score6:  1350
# score1:  12400 score2:  6500 score3:  6550 score4:  11150 score5:  10000 score6:  9500
# score1:  6950 score2:  3950 score3:  5300 score4:  10300 score5:  3750 score6:  2350
# score1:  7850 score2:  1600 score3:  6950 score4:  5050 score5:  5100 score6:  11950
# score1:  8700 score2:  6500 score3:  6400 score4:  6800 score5:  8400 score6:  11950
# score1:  12500 score2:  3300 score3:  3700 score4:  2450 score5:  6600 score6:  3050
# score1:  9350 score2:  3900 score3:  5300 score4:  11050 score5:  5950 score6:  9850
# score1:  8150 score2:  7000 score3:  7050 score4:  11350 score5:  4300 score6:  10000
# score1:  7800 score2:  3200 score3:  1450 score4:  9550 score5:  8500 score6:  12300
# score1:  8500 score2:  5250 score3:  5450 score4:  5200 score5:  10500 score6:  9000
# score1:  6450 score2:  2400 score3:  5350 score4:  10900 score5:  3750 score6:  7400
# score1:  12700 score2:  8900 score3:  6450 score4:  7250 score5:  6400 score6:  9250
# score1:  10350 score2:  0 score3:  4000 score4:  8700 score5:  8650 score6:  7550
# score1:  9550 score2:  2150 score3:  2600 score4:  5100 score5:  6300 score6:  12200
# score1:  4500 score2:  1000 score3:  3600 score4:  11650 score5:  4650 score6:  10600
# score1:  4700 score2:  3300 score3:  3950 score4:  5200 score5:  11600 score6:  3200
# score1:  10050 score2:  1900 score3:  3250 score4:  8300 score5:  4700 score6:  5200
# score1:  5850 score2:  3750 score3:  2300 score4:  13000 score5:  10200 score6:  7250
# score1:  10150 score2:  4250 score3:  2900 score4:  4550 score5:  11450 score6:  10900
# score1:  10550 score2:  5150 score3:  3600 score4:  8600 score5:  4200 score6:  4300
# score1:  6200 score2:  5700 score3:  6450 score4:  5500 score5:  10150 score6:  9700
# score1:  2600 score2:  4300 score3:  4700 score4:  11650 score5:  7850 score6:  4000
# score1:  2750 score2:  2150 score3:  3250 score4:  6350 score5:  11450 score6:  3950
# score1:  11500 score2:  2300 score3:  2000 score4:  6450 score5:  7050 score6:  2900
# score1:  2750 score2:  4850 score3:  4550 score4:  7450 score5:  6750 score6:  12700
# score1:  6900 score2:  5550 score3:  3250 score4:  11900 score5:  8350 score6:  3550
# score1:  8350 score2:  4200 score3:  6200 score4:  10200 score5:  6750 score6:  10250
# score1:  9650 score2:  7950 score3:  6150 score4:  12200 score5:  7600 score6:  5700
# score1:  10350 score2:  6550 score3:  6750 score4:  6900 score5:  8150 score6:  10300
# score1:  2300 score2:  1300 score3:  4850 score4:  4400 score5:  2600 score6:  10650
# score1:  8950 score2:  5900 score3:  4550 score4:  10450 score5:  7500 score6:  10100
# score1:  9300 score2:  6650 score3:  8200 score4:  10550 score5:  3600 score6:  10350
# score1:  10750 score2:  4000 score3:  6600 score4:  9150 score5:  6850 score6:  6600
# score1:  10950 score2:  4650 score3:  3550 score4:  9550 score5:  6400 score6:  8100
# score1:  6650 score2:  2150 score3:  2700 score4:  8350 score5:  8400 score6:  10100
# score1:  2100 score2:  6000 score3:  5400 score4:  12600 score5:  6850 score6:  5150
# score1:  7500 score2:  6800 score3:  7650 score4:  11450 score5:  9950 score6:  8600
# score1:  10400 score2:  5100 score3:  2950 score4:  9200 score5:  9650 score6:  10200
# score1:  4750 score2:  4150 score3:  4150 score4:  6800 score5:  3300 score6:  11550
# score1:  8550 score2:  4800 score3:  4500 score4:  7000 score5:  9050 score6:  10100
# score1:  8750 score2:  2750 score3:  6900 score4:  11000 score5:  9450 score6:  9550
# score1:  6600 score2:  9100 score3:  7300 score4:  8850 score5:  10100 score6:  8150
# score1:  10250 score2:  4150 score3:  1100 score4:  6400 score5:  8700 score6:  5950
# score1:  13200 score2:  8450 score3:  5650 score4:  7100 score5:  7850 score6:  12050
# score1:  7000 score2:  7850 score3:  3300 score4:  10050 score5:  4450 score6:  9050
# score1:  10650 score2:  5500 score3:  8900 score4:  8400 score5:  6950 score6:  7000
# score1:  6900 score2:  5350 score3:  3750 score4:  13550 score5:  4950 score6:  11450
# score1:  9000 score2:  3850 score3:  4150 score4:  6850 score5:  13750 score6:  7000
# score1:  7900 score2:  6050 score3:  5300 score4:  10250 score5:  7900 score6:  12250
# score1:  2800 score2:  4750 score3:  2400 score4:  11900 score5:  2700 score6:  4300
# score1:  10700 score2:  5600 score3:  7500 score4:  7150 score5:  10000 score6:  8600
# score1:  7900 score2:  4650 score3:  6050 score4:  9800 score5:  10500 score6:  4650
# score1:  7000 score2:  4350 score3:  4550 score4:  10650 score5:  3350 score6:  2350
# score1:  6050 score2:  5700 score3:  4050 score4:  9850 score5:  9250 score6:  11350
# score1:  11550 score2:  4350 score3:  2950 score4:  8600 score5:  6550 score6:  2750
# score1:  10300 score2:  5400 score3:  3400 score4:  11950 score5:  6500 score6:  5850
# score1:  3500 score2:  2200 score3:  1750 score4:  4150 score5:  7800 score6:  10150
# score1:  11000 score2:  3800 score3:  3650 score4:  7100 score5:  6150 score6:  7800
# score1:  5800 score2:  4950 score3:  3250 score4:  9900 score5:  10700 score6:  8000
# score1:  10700 score2:  7800 score3:  1600 score4:  11300 score5:  8500 score6:  7450
# score1:  5900 score2:  8600 score3:  4750 score4:  5800 score5:  5200 score6:  10050
# score1:  6600 score2:  4850 score3:  1200 score4:  10800 score5:  6800 score6:  6200
# score1:  10550 score2:  3050 score3:  2600 score4:  6400 score5:  5750 score6:  7350
# score1:  5500 score2:  2100 score3:  3300 score4:  9000 score5:  4950 score6:  14500
# score1:  7350 score2:  5400 score3:  5200 score4:  10900 score5:  5350 score6:  9200
# score1:  6350 score2:  5150 score3:  5650 score4:  5100 score5:  11300 score6:  8400
# score1:  2250 score2:  3250 score3:  1800 score4:  6450 score5:  11800 score6:  4900
# score1:  10750 score2:  3200 score3:  4900 score4:  9550 score5:  10900 score6:  5300
# score1:  5150 score2:  6650 score3:  4900 score4:  10300 score5:  8200 score6:  11650
# score1:  5700 score2:  6550 score3:  4300 score4:  9600 score5:  8500 score6:  11100
# score1:  9400 score2:  3900 score3:  2700 score4:  6750 score5:  12800 score6:  6650
# score1:  10100 score2:  2600 score3:  0 score4:  4600 score5:  8700 score6:  5700
# score1:  2250 score2:  2400 score3:  5450 score4:  8500 score5:  5250 score6:  11000
# score1:  10950 score2:  5000 score3:  7500 score4:  6950 score5:  4000 score6:  6650
# score1:  13200 score2:  6250 score3:  2950 score4:  7650 score5:  7750 score6:  5500
# score1:  10250 score2:  4600 score3:  4900 score4:  6850 score5:  3700 score6:  8400
# score1:  6500 score2:  7800 score3:  4350 score4:  4900 score5:  11650 score6:  8850
# score1:  11700 score2:  0 score3:  6950 score4:  7200 score5:  2700 score6:  9600
# score1:  6600 score2:  5000 score3:  7050 score4:  6800 score5:  6150 score6:  10900
# score1:  11150 score2:  1700 score3:  3550 score4:  4350 score5:  5500 score6:  5850
# score1:  3150 score2:  4050 score3:  3750 score4:  3500 score5:  10500 score6:  10350
# score1:  4700 score2:  7250 score3:  3650 score4:  9700 score5:  2450 score6:  13100
# score1:  2400 score2:  1750 score3:  5200 score4:  6800 score5:  11100 score6:  4600
# score1:  11950 score2:  5600 score3:  4350 score4:  7450 score5:  3900 score6:  7550
# score1:  8050 score2:  4400 score3:  4200 score4:  10400 score5:  7550 score6:  12800
# score1:  4700 score2:  500 score3:  3350 score4:  11900 score5:  0 score6:  6100
# score1:  7900 score2:  5150 score3:  7100 score4:  9650 score5:  7400 score6:  10150
# score1:  5250 score2:  7150 score3:  4600 score4:  8250 score5:  6250 score6:  11000
# score1:  9300 score2:  9550 score3:  9300 score4:  11500 score5:  7900 score6:  10950
# score1:  11450 score2:  7500 score3:  1750 score4:  9550 score5:  4350 score6:  7600
# score1:  10900 score2:  4800 score3:  3350 score4:  7300 score5:  7100 score6:  8600
# score1:  7750 score2:  3900 score3:  5700 score4:  7800 score5:  8800 score6:  11300
# score1:  3500 score2:  3700 score3:  2100 score4:  10950 score5:  5600 score6:  8500
# score1:  4950 score2:  3550 score3:  2300 score4:  10450 score5:  5500 score6:  9150
# score1:  9250 score2:  2750 score3:  5850 score4:  11150 score5:  7600 score6:  8650
# score1:  9500 score2:  6000 score3:  5550 score4:  6950 score5:  9900 score6:  11900
# score1:  1950 score2:  2700 score3:  0 score4:  2200 score5:  9200 score6:  11100
# score1:  11500 score2:  8000 score3:  4200 score4:  9500 score5:  10000 score6:  10050
# score1:  9500 score2:  5850 score3:  3250 score4:  10900 score5:  9500 score6:  10000
# score1:  7350 score2:  4700 score3:  5100 score4:  7850 score5:  11100 score6:  10150
# score1:  4900 score2:  4300 score3:  4850 score4:  9150 score5:  11250 score6:  4700
# score1:  4800 score2:  3850 score3:  3650 score4:  2600 score5:  10800 score6:  5600
# score1:  7200 score2:  3800 score3:  1750 score4:  3850 score5:  10950 score6:  4850
# score1:  7500 score2:  4050 score3:  6500 score4:  7250 score5:  10350 score6:  7850
# score1:  9350 score2:  4900 score3:  3750 score4:  10850 score5:  6150 score6:  4500
# score1:  9050 score2:  6200 score3:  6300 score4:  10050 score5:  11100 score6:  8400
# score1:  11750 score2:  3150 score3:  5200 score4:  7300 score5:  4400 score6:  6150
# score1:  6650 score2:  4150 score3:  2650 score4:  7200 score5:  7050 score6:  10800
# score1:  7800 score2:  6750 score3:  4400 score4:  10800 score5:  11050 score6:  6700
# score1:  7200 score2:  3650 score3:  4600 score4:  11150 score5:  1650 score6:  3100
# score1:  10650 score2:  1150 score3:  500 score4:  7100 score5:  8500 score6:  9750
# score1:  12500 score2:  4250 score3:  8400 score4:  7550 score5:  8800 score6:  10400
# score1:  8500 score2:  3700 score3:  7050 score4:  10000 score5:  6600 score6:  6300
# score1:  8050 score2:  3650 score3:  7600 score4:  6850 score5:  11450 score6:  9900
# score1:  9550 score2:  2700 score3:  7000 score4:  10400 score5:  6100 score6:  10450
# score1:  5600 score2:  6400 score3:  3350 score4:  12200 score5:  7500 score6:  8400
# score1:  10050 score2:  5350 score3:  6400 score4:  6800 score5:  5700 score6:  7350
# score1:  4100 score2:  5150 score3:  2700 score4:  11250 score5:  5150 score6:  5600
# score1:  750 score2:  2600 score3:  4000 score4:  7400 score5:  12800 score6:  5650
# score1:  3150 score2:  1200 score3:  2200 score4:  11650 score5:  7150 score6:  3650
# score1:  11350 score2:  3900 score3:  6500 score4:  10400 score5:  6400 score6:  6850
# score1:  4800 score2:  3950 score3:  2550 score4:  2750 score5:  6050 score6:  14300
# score1:  7900 score2:  6800 score3:  4000 score4:  4850 score5:  4500 score6:  11400
# score1:  14250 score2:  4150 score3:  6050 score4:  9600 score5:  6350 score6:  10400
# score1:  8750 score2:  7500 score3:  5850 score4:  10750 score5:  8650 score6:  11100
# score1:  12250 score2:  4750 score3:  3600 score4:  6500 score5:  7900 score6:  9550
# score1:  11100 score2:  4200 score3:  5400 score4:  8600 score5:  8350 score6:  10100
# score1:  10100 score2:  9050 score3:  3850 score4:  6200 score5:  9400 score6:  10900
# score1:  3550 score2:  2700 score3:  2500 score4:  11300 score5:  2650 score6:  6850
# score1:  5450 score2:  7300 score3:  5350 score4:  10900 score5:  14000 score6:  7600
# score1:  5200 score2:  3700 score3:  5400 score4:  10700 score5:  5950 score6:  2100
# score1:  4700 score2:  6900 score3:  4200 score4:  5300 score5:  11150 score6:  8600
# score1:  10750 score2:  10350 score3:  4850 score4:  4900 score5:  10050 score6:  7200
# score1:  8950 score2:  2750 score3:  2600 score4:  10250 score5:  11600 score6:  2300
# score1:  5600 score2:  5200 score3:  5500 score4:  9550 score5:  11150 score6:  12650
# score1:  8100 score2:  5600 score3:  5400 score4:  10700 score5:  11350 score6:  8750
# score1:  11100 score2:  700 score3:  5950 score4:  5700 score5:  4600 score6:  11600
# score1:  9700 score2:  4600 score3:  3900 score4:  5150 score5:  5800 score6:  12500
# score1:  10200 score2:  1650 score3:  4450 score4:  5300 score5:  5300 score6:  7600
# score1:  7500 score2:  7150 score3:  7350 score4:  8950 score5:  13650 score6:  5200
# score1:  5150 score2:  3850 score3:  2750 score4:  3850 score5:  9350 score6:  10300
# score1:  8350 score2:  9750 score3:  6200 score4:  10550 score5:  4900 score6:  12200
# score1:  10200 score2:  3500 score3:  9350 score4:  10200 score5:  9350 score6:  11950
# score1:  10850 score2:  4750 score3:  4900 score4:  11700 score5:  8550 score6:  7700
# score1:  5750 score2:  4400 score3:  6450 score4:  10600 score5:  7500 score6:  10700
# score1:  10200 score2:  7050 score3:  6100 score4:  7850 score5:  7650 score6:  10250
# score1:  12050 score2:  3800 score3:  1750 score4:  9050 score5:  5450 score6:  8050
# score1:  11300 score2:  3850 score3:  3500 score4:  10550 score5:  4800 score6:  5700
# score1:  10800 score2:  3350 score3:  3150 score4:  9800 score5:  7500 score6:  8050
# score1:  12000 score2:  7450 score3:  4500 score4:  7550 score5:  7600 score6:  7250
# score1:  12550 score2:  9100 score3:  7050 score4:  8700 score5:  5100 score6:  12150
# score1:  9900 score2:  6300 score3:  4800 score4:  5350 score5:  5950 score6:  13300
# score1:  9800 score2:  3900 score3:  4300 score4:  10150 score5:  10850 score6:  7000
# score1:  12100 score2:  4600 score3:  3400 score4:  4950 score5:  7800 score6:  8700
# score1:  10450 score2:  2850 score3:  2300 score4:  10100 score5:  7500 score6:  9450
# score1:  1250 score2:  2900 score3:  5000 score4:  9400 score5:  6000 score6:  12100
# score1:  10200 score2:  4900 score3:  2300 score4:  7500 score5:  7000 score6:  6950
# score1:  9600 score2:  3750 score3:  4050 score4:  8750 score5:  8300 score6:  12800
# score1:  9850 score2:  2700 score3:  4350 score4:  11850 score5:  8650 score6:  8100
# score1:  10900 score2:  4600 score3:  500 score4:  4150 score5:  9150 score6:  8550
# score1:  6000 score2:  3100 score3:  9800 score4:  10400 score5:  8250 score6:  8950
# score1:  6000 score2:  4650 score3:  5650 score4:  4750 score5:  5050 score6:  10600
# score1:  3700 score2:  2750 score3:  1100 score4:  6000 score5:  10550 score6:  1250
# score1:  7200 score2:  7550 score3:  6300 score4:  9550 score5:  10550 score6:  8050
# score1:  13700 score2:  3450 score3:  2000 score4:  3500 score5:  7200 score6:  2950
# score1:  14000 score2:  3050 score3:  3350 score4:  11100 score5:  6800 score6:  4750
# score1:  2900 score2:  4100 score3:  4300 score4:  7800 score5:  11600 score6:  6550
# score1:  5650 score2:  3950 score3:  7100 score4:  8250 score5:  6850 score6:  11650
# score1:  8000 score2:  4550 score3:  2250 score4:  6100 score5:  9800 score6:  10600
# score1:  2950 score2:  5300 score3:  700 score4:  4350 score5:  10950 score6:  4100
# score1:  9500 score2:  7350 score3:  2550 score4:  7700 score5:  9100 score6:  12550
# score1:  10150 score2:  4650 score3:  5800 score4:  10150 score5:  10500 score6:  7350
# score1:  10800 score2:  5600 score3:  5150 score4:  8500 score5:  8350 score6:  5150
# 0.2771 0.0039 0.0041 0.243 0.1889 0.283

# %%
wins = [0,0,0,0,0,0]
numRun = 10000
minScore = 0
for i in range(numRun):
    score = [0,0,0,0,0,0]
    for j in range(100):
        score[0] += strategy2(minScore, 0)
        score[1] += strategy2(minScore, 100)
        score[2] += strategy2(minScore, 200)
        score[3] += strategy2(minScore, 300)
        score[4] += strategy2(minScore, 400)
        score[5] += strategy2(minScore, 500)
        if any(score[i]>=10000 for i in range(len(score))):
            score[0] += strategy2(minScore, 0)
            score[1] += strategy2(minScore, 100)
            score[2] += strategy2(minScore, 200)
            score[3] += strategy2(minScore, 300)
            score[4] += strategy2(minScore, 400)
            score[5] += strategy2(minScore, 500)
            wins[score.index(max(score))] += 1
            break
    # print("score1: ", score[0], "score2: ", score[1], "score3: ", score[2],
    #       "score4: ", score[3], "score5: ", score[4], "score6: ", score[5])
print(wins[0]/numRun, wins[1]/numRun, wins[2]/numRun, wins[3]/numRun, wins[4]/numRun, wins[5]/numRun)
# Out:
# 0.1667 0.168 0.1706 0.1626 0.1654 0.1667
